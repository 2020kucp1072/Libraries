# %%
'''
    @Author: VEMULA DILEEP
    @Date: 25-10-24
    @Last Modified by: VEMULA DILEEP
    @Last Modified time: 17:55
    @Title : Python programs for matplotlib - pie plot
'''

import matplotlib.pyplot as plt
import pandas as pd

# 1. Pie chart of programming languages popularity
def pie_chart_popularity():
    """
    Description: Creates a pie chart for the popularity of programming languages.
    Parameters: None
    Returns: None
    """
    languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    
    plt.figure(figsize=(8, 6))
    plt.pie(popularity, labels=languages, autopct='%1.1f%%', startangle=140)
    plt.show()

# 2. Pie chart with title of programming languages popularity
def pie_chart_with_title():
    """
    Description: Creates a pie chart with a title for the popularity of programming languages.
    Parameters: None
    Returns: None
    """
    languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    
    plt.figure(figsize=(8, 6))
    plt.pie(popularity, labels=languages, autopct='%1.1f%%', startangle=140)
    plt.title('Popularity of Programming Languages')
    plt.show()

# 3. Pie chart of gold medal achievements in 2016 Olympics
def pie_chart_gold_medals():
    """
    Description: Creates a pie chart of the gold medals achievements in the 2016 Olympics.
    Parameters: None
    Returns: None
    """
    # Load data from csv file
    data = pd.read_csv("medal.csv")
    countries = data['country']
    gold_medals = data['gold_medal']
    
    plt.figure(figsize=(8, 6))
    plt.pie(gold_medals, labels=countries, autopct='%1.1f%%', startangle=140)
    plt.title('Gold Medals in 2016 Summer Olympics')
    plt.show()

# Main function to call each individual function
def main():
    pie_chart_popularity()
    pie_chart_with_title()
    pie_chart_gold_medals()

# Run main function
if __name__ == "__main__":
    main()
